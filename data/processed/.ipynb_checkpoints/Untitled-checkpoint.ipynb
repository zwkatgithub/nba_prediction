# %%
import pandas as pd
data = pd.read_csv('data.csv',sep=',')

# %%
data.head(1)
# Out:
#                                                                                                                                                                                                                                          fg_pct  \
# -0.015 0.031 -1.3 -0.014 -0.04 -0.013 -0.5 0.1 -0.1 0.1 3.6 0.013 -0.143 2.0 0.01 0.12 0.066 0.6 0.0 0.7 -0.8 5.6 0.032 0.0 -0.9 -0.019 -0.089 0.067 -0.6 0.3 -1.0 -0.5 2.1 -0.04 0.03 -4.0 -0.019 0.006 -0.188 -1.1 -0.7 -0.1 -0.9 2.3   0.063
#
#                                                                                                                                                                                                                                           three_pt_pct  \
# -0.015 0.031 -1.3 -0.014 -0.04 -0.013 -0.5 0.1 -0.1 0.1 3.6 0.013 -0.143 2.0 0.01 0.12 0.066 0.6 0.0 0.7 -0.8 5.6 0.032 0.0 -0.9 -0.019 -0.089 0.067 -0.6 0.3 -1.0 -0.5 2.1 -0.04 0.03 -4.0 -0.019 0.006 -0.188 -1.1 -0.7 -0.1 -0.9 2.3         -0.084
#
# ...
